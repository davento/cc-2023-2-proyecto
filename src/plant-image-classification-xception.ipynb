# %% [markdown]
# # Image Classification

# %% [markdown]
# ## Importing Libraries

# %%
#Importing os, glob and cv2 to read and import data
import os
import cv2
import glob

#Importing tqdm for the progress bar
from tqdm import tqdm

#Importing numpy and pandas for data manipulation
import numpy as np
import pandas as pd

#Import random for randomness
import random

#Importing matplotlib.pyplot for visual representation
import matplotlib.pyplot as plt

#Importing One Hot Encoder:
from sklearn.preprocessing import OneHotEncoder

#Importing train test split
from sklearn.model_selection import train_test_split

#Setting seed
seed = 5901
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input,Dense,Conv2D,Add
from tensorflow.keras.layers import SeparableConv2D,ReLU
from tensorflow.keras.layers import BatchNormalization,MaxPool2D
from tensorflow.keras.layers import GlobalAvgPool2D
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
import time

# %% [markdown]
# ## Loading data

# %%
#Initializing the path of the datasets
trainPath = "/kaggle/input/plant-seedlings-classification-cs429529/train"
testPath = "/kaggle/input/plant-seedlings-classification-cs429529/test"

# %%
def loadData(path):
    X = []
    Y = []
    for y in os.listdir(path):
        if y != '.DS_Store':
            for img in glob.glob(path + "/" + y +"/*.png"):
                #reads the image as Blue-Green-Red
                image = cv2.imread(img)
                #converts the image to red-green-blue
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, (70, 70))
                X.append(image)
                Y.append(y)
    return X, Y

# %%
X,Y = loadData(trainPath)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# Showing samples

# %%
def plotData(X, Y, col=4):
    label = set(Y)
    n = len(label)
    row = n // col
    if np.mod(n, col) != 0:
        row += 1
    fig, axs = plt.subplots(row, col, figsize=(10, 10))
    i = 0
    for y in label:
        index = random.choice(np.where(np.array(Y) == y)[0])
        axs[i // col, i % col].imshow(X[index])
        axs[i // col, i % col].axis("off")
        axs[i // col, i % col].set_title(y)
        i += 1
    for j in range(i, row * col):
        axs[j // col, j % col].axis("off")
    plt.show()

# %%
plotData(X, Y)

# %% [markdown]
# Data distribution per class

# %%
def classPlot(Y):
    pd.DataFrame(Y)[0].value_counts().plot(kind='bar')

# %%
classPlot(Y)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Utility functions

# %%
#Perform Gaussian Blur to reduce Noise
def gaussianBlur(img):
    return cv2.GaussianBlur(img, (5,5), 0)

#Convert Image to HSV (Hue - Saturation - Value) to represent the color range better for masking
def HSV(img):
    return cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

#Creating boolean mask to segment the leaves in the image
def Mask(img):
    lGreen = (20, 40, 50)
    uGreen = (75, 255, 255)
    mask = cv2.inRange(img, lGreen, uGreen)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (11, 11))
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    return mask > 0

def applyMask(img, showImg=False):
    
    gImg = gaussianBlur(img)
    hsvImg = HSV(gImg)
    amImg = np.zeros_like(img, np.uint8)
    mask = Mask(hsvImg)
    
    #Image Segmentation
    amImg[mask] = img[mask]
    
    if showImg:
        plt.subplot(2, 3, 1); plt.imshow(img); plt.title("Orginal Image")
        plt.subplot(2, 3, 2); plt.imshow(gImg); plt.title("Blur Image")
        plt.subplot(2, 3, 3); plt.imshow(hsvImg); plt.title("HSV Image")
        plt.subplot(2, 3, 4); plt.imshow(mask); plt.title("Mask")
        plt.subplot(2, 3, 5); plt.imshow(amImg); plt.title("Segmented Image")
    
    return amImg

#Normalizing the value to be between 0 to 1
def norm(data):
    return data/255

#One hot encoding the Class Values:
def oneHot(Y):
    Y = np.array(Y).reshape(-1, 1)
    encoder = OneHotEncoder()
    return encoder.fit_transform(Y), encoder

def decode(encoder, yPred):
    return np.array(encoder.categories_[0])[yPred]

# %% [markdown]
# ### Testing the masking process

# %%
sample = applyMask(X[10], True)

# %% [markdown]
# ### Applying the preprocessing to the Data

# %%
def preprocessing(X, Y):
    ppX = []
    for img in X:
        ppX.append(applyMask(img))
    ppX = np.array(ppX)
    normX = norm(ppX)
    ohY, encoder = oneHot(Y)
    return normX, ohY.toarray(), encoder

# %%
ppX, ppY, encoder = preprocessing(X, Y)

# %% [markdown]
# ### Training/Testing Split

# %%
trainX, valX, trainY, valY = train_test_split(ppX, ppY, test_size=0.33, random_state=seed, stratify = ppY)

# %% [markdown]
# ### Data Augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
        rotation_range=180,  # randomly rotate images in the range
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally
        height_shift_range=0.1,  # randomly shift images vertically 
        horizontal_flip=True,  # randomly flip images horizontally
        vertical_flip=True  # randomly flip images vertically
    )  
datagen.fit(trainX)

# %% [markdown]
# ## Testing with X-ception

# %% [markdown]
# ### Defining the Model Architecture
#
# Code referenced from [A. Sarkar (2020)](https://towardsdatascience.com/xception-from-scratch-using-tensorflow-even-better-than-inception-940fb231ced9).

# %%
def conv_bn(x, filters, kernel_size, strides=1):
    
    x = Conv2D(filters=filters, 
               kernel_size = kernel_size, 
               strides=strides, 
               padding = 'same', 
               use_bias = False)(x)
    x = BatchNormalization()(x)
    return x
# creating separableConv-Batch Norm block

def sep_bn(x, filters, kernel_size, strides=1):
    
    x = SeparableConv2D(filters=filters, 
                        kernel_size = kernel_size, 
                        strides=strides, 
                        padding = 'same', 
                        use_bias = False)(x)
    x = BatchNormalization()(x)
    return x
# entry flow

def entry_flow(x):
    
    x = conv_bn(x, filters =32, kernel_size =3, strides=2)
    x = ReLU()(x)
    x = conv_bn(x, filters =64, kernel_size =3, strides=1)
    tensor = ReLU()(x)
    
    x = sep_bn(tensor, filters = 128, kernel_size =3)
    x = ReLU()(x)
    x = sep_bn(x, filters = 128, kernel_size =3)
    x = MaxPool2D(pool_size=3, strides=2, padding = 'same')(x)
    
    tensor = conv_bn(tensor, filters=128, kernel_size = 1,strides=2)
    x = Add()([tensor,x])
    
    x = ReLU()(x)
    x = sep_bn(x, filters =256, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters =256, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding = 'same')(x)
    
    tensor = conv_bn(tensor, filters=256, kernel_size = 1,strides=2)
    x = Add()([tensor,x])
    
    x = ReLU()(x)
    x = sep_bn(x, filters =728, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters =728, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding = 'same')(x)
    
    tensor = conv_bn(tensor, filters=728, kernel_size = 1,strides=2)
    x = Add()([tensor,x])
    return x

# middle flow

def middle_flow(tensor):
    
    for _ in range(8):
        x = ReLU()(tensor)
        x = sep_bn(x, filters = 728, kernel_size = 3)
        x = ReLU()(x)
        x = sep_bn(x, filters = 728, kernel_size = 3)
        x = ReLU()(x)
        x = sep_bn(x, filters = 728, kernel_size = 3)
        x = ReLU()(x)
        tensor = Add()([tensor,x])
        
    return tensor
# exit flow

def exit_flow(tensor):
    
    x = ReLU()(tensor)
    x = sep_bn(x, filters = 728,  kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters = 1024,  kernel_size=3)
    x = MaxPool2D(pool_size = 3, strides = 2, padding ='same')(x)
    
    tensor = conv_bn(tensor, filters =1024, kernel_size=1, strides =2)
    x = Add()([tensor,x])
    
    x = sep_bn(x, filters = 1536,  kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters = 2048,  kernel_size=3)
    x = GlobalAvgPool2D()(x)
    
    x = Dense (units = 12, activation = 'softmax')(x)
    
    return x

# %% [markdown]
# ### Building the model

# %%
# model code

input = Input(shape = (70,70,3))
x = entry_flow(input)
x = middle_flow(x)
output = exit_flow(x)

model = Model (inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 70, 70, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 35, 35, 32)   864         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 35, 35, 32)  128         ['conv2d[0][0]']
#  alization)
#
#  re_lu (ReLU)                   (None, 35, 35, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 35, 35, 64)   18432       ['re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 35, 35, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 35, 35, 64)   0           ['batch_normalization_1[0][0]']
#
#  separable_conv2d (SeparableCon  (None, 35, 35, 128)  8768       ['re_lu_1[0][0]']
#  v2D)
#
#  batch_normalization_2 (BatchNo  (None, 35, 35, 128)  512        ['separable_conv2d[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 35, 35, 128)  0           ['batch_normalization_2[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 35, 35, 128)  17536      ['re_lu_2[0][0]']
#  onv2D)
#
#  conv2d_2 (Conv2D)              (None, 18, 18, 128)  8192        ['re_lu_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 35, 35, 128)  512        ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 18, 18, 128)  512        ['conv2d_2[0][0]']
#  rmalization)
#
#  max_pooling2d (MaxPooling2D)   (None, 18, 18, 128)  0           ['batch_normalization_3[0][0]']
#
#  add (Add)                      (None, 18, 18, 128)  0           ['batch_normalization_4[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 18, 18, 128)  0           ['add[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 18, 18, 256)  33920      ['re_lu_3[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 18, 18, 256)  1024       ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 18, 18, 256)  0           ['batch_normalization_5[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 18, 18, 256)  67840      ['re_lu_4[0][0]']
#  onv2D)
#
#  conv2d_3 (Conv2D)              (None, 9, 9, 256)    32768       ['batch_normalization_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 18, 18, 256)  1024       ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 9, 9, 256)   1024        ['conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 9, 9, 256)   0           ['batch_normalization_6[0][0]']
#
#  add_1 (Add)                    (None, 9, 9, 256)    0           ['batch_normalization_7[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 9, 9, 256)    0           ['add_1[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 9, 9, 728)   188672      ['re_lu_5[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 9, 9, 728)   2912        ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 9, 9, 728)    0           ['batch_normalization_8[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 9, 9, 728)   536536      ['re_lu_6[0][0]']
#  onv2D)
#
#  conv2d_4 (Conv2D)              (None, 5, 5, 728)    186368      ['batch_normalization_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 9, 9, 728)   2912        ['separable_conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 5, 5, 728)   2912        ['conv2d_4[0][0]']
#  ormalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 5, 5, 728)   0           ['batch_normalization_9[0][0]']
#
#  add_2 (Add)                    (None, 5, 5, 728)    0           ['batch_normalization_10[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  re_lu_7 (ReLU)                 (None, 5, 5, 728)    0           ['add_2[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 5, 5, 728)   536536      ['re_lu_7[0][0]']
#  onv2D)
#
#  batch_normalization_11 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_6[0][0]']
#  ormalization)
#
#  re_lu_8 (ReLU)                 (None, 5, 5, 728)    0           ['batch_normalization_11[0][0]']
#
#  separable_conv2d_7 (SeparableC  (None, 5, 5, 728)   536536      ['re_lu_8[0][0]']
#  onv2D)
#
#  batch_normalization_12 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_7[0][0]']
#  ormalization)
#
#  re_lu_9 (ReLU)                 (None, 5, 5, 728)    0           ['batch_normalization_12[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 5, 5, 728)   536536      ['re_lu_9[0][0]']
#  onv2D)
#
#  batch_normalization_13 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_8[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_13[0][0]']
#
#  add_3 (Add)                    (None, 5, 5, 728)    0           ['add_2[0][0]',
#                                                                   're_lu_10[0][0]']
#
#  re_lu_11 (ReLU)                (None, 5, 5, 728)    0           ['add_3[0][0]']
#
#  separable_conv2d_9 (SeparableC  (None, 5, 5, 728)   536536      ['re_lu_11[0][0]']
#  onv2D)
#
#  batch_normalization_14 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_9[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_14[0][0]']
#
#  separable_conv2d_10 (Separable  (None, 5, 5, 728)   536536      ['re_lu_12[0][0]']
#  Conv2D)
#
#  batch_normalization_15 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_10[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_15[0][0]']
#
#  separable_conv2d_11 (Separable  (None, 5, 5, 728)   536536      ['re_lu_13[0][0]']
#  Conv2D)
#
#  batch_normalization_16 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_16[0][0]']
#
#  add_4 (Add)                    (None, 5, 5, 728)    0           ['add_3[0][0]',
#                                                                   're_lu_14[0][0]']
#
#  re_lu_15 (ReLU)                (None, 5, 5, 728)    0           ['add_4[0][0]']
#
#  separable_conv2d_12 (Separable  (None, 5, 5, 728)   536536      ['re_lu_15[0][0]']
#  Conv2D)
#
#  batch_normalization_17 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_12[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_17[0][0]']
#
#  separable_conv2d_13 (Separable  (None, 5, 5, 728)   536536      ['re_lu_16[0][0]']
#  Conv2D)
#
#  batch_normalization_18 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_13[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_18[0][0]']
#
#  separable_conv2d_14 (Separable  (None, 5, 5, 728)   536536      ['re_lu_17[0][0]']
#  Conv2D)
#
#  batch_normalization_19 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_14[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_19[0][0]']
#
#  add_5 (Add)                    (None, 5, 5, 728)    0           ['add_4[0][0]',
#                                                                   're_lu_18[0][0]']
#
#  re_lu_19 (ReLU)                (None, 5, 5, 728)    0           ['add_5[0][0]']
#
#  separable_conv2d_15 (Separable  (None, 5, 5, 728)   536536      ['re_lu_19[0][0]']
#  Conv2D)
#
#  batch_normalization_20 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_15[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_20[0][0]']
#
#  separable_conv2d_16 (Separable  (None, 5, 5, 728)   536536      ['re_lu_20[0][0]']
#  Conv2D)
#
#  batch_normalization_21 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_16[0][0]']
#  ormalization)
#
#  re_lu_21 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_21[0][0]']
#
#  separable_conv2d_17 (Separable  (None, 5, 5, 728)   536536      ['re_lu_21[0][0]']
#  Conv2D)
#
#  batch_normalization_22 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_17[0][0]']
#  ormalization)
#
#  re_lu_22 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_22[0][0]']
#
#  add_6 (Add)                    (None, 5, 5, 728)    0           ['add_5[0][0]',
#                                                                   're_lu_22[0][0]']
#
#  re_lu_23 (ReLU)                (None, 5, 5, 728)    0           ['add_6[0][0]']
#
#  separable_conv2d_18 (Separable  (None, 5, 5, 728)   536536      ['re_lu_23[0][0]']
#  Conv2D)
#
#  batch_normalization_23 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_18[0][0]']
#  ormalization)
#
#  re_lu_24 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_23[0][0]']
#
#  separable_conv2d_19 (Separable  (None, 5, 5, 728)   536536      ['re_lu_24[0][0]']
#  Conv2D)
#
#  batch_normalization_24 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_19[0][0]']
#  ormalization)
#
#  re_lu_25 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_24[0][0]']
#
#  separable_conv2d_20 (Separable  (None, 5, 5, 728)   536536      ['re_lu_25[0][0]']
#  Conv2D)
#
#  batch_normalization_25 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_20[0][0]']
#  ormalization)
#
#  re_lu_26 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_25[0][0]']
#
#  add_7 (Add)                    (None, 5, 5, 728)    0           ['add_6[0][0]',
#                                                                   're_lu_26[0][0]']
#
#  re_lu_27 (ReLU)                (None, 5, 5, 728)    0           ['add_7[0][0]']
#
#  separable_conv2d_21 (Separable  (None, 5, 5, 728)   536536      ['re_lu_27[0][0]']
#  Conv2D)
#
#  batch_normalization_26 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_21[0][0]']
#  ormalization)
#
#  re_lu_28 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_26[0][0]']
#
#  separable_conv2d_22 (Separable  (None, 5, 5, 728)   536536      ['re_lu_28[0][0]']
#  Conv2D)
#
#  batch_normalization_27 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_22[0][0]']
#  ormalization)
#
#  re_lu_29 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_27[0][0]']
#
#  separable_conv2d_23 (Separable  (None, 5, 5, 728)   536536      ['re_lu_29[0][0]']
#  Conv2D)
#
#  batch_normalization_28 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_23[0][0]']
#  ormalization)
#
#  re_lu_30 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_28[0][0]']
#
#  add_8 (Add)                    (None, 5, 5, 728)    0           ['add_7[0][0]',
#                                                                   're_lu_30[0][0]']
#
#  re_lu_31 (ReLU)                (None, 5, 5, 728)    0           ['add_8[0][0]']
#
#  separable_conv2d_24 (Separable  (None, 5, 5, 728)   536536      ['re_lu_31[0][0]']
#  Conv2D)
#
#  batch_normalization_29 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_24[0][0]']
#  ormalization)
#
#  re_lu_32 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_29[0][0]']
#
#  separable_conv2d_25 (Separable  (None, 5, 5, 728)   536536      ['re_lu_32[0][0]']
#  Conv2D)
#
#  batch_normalization_30 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_25[0][0]']
#  ormalization)
#
#  re_lu_33 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_30[0][0]']
#
#  separable_conv2d_26 (Separable  (None, 5, 5, 728)   536536      ['re_lu_33[0][0]']
#  Conv2D)
#
#  batch_normalization_31 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_26[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_31[0][0]']
#
#  add_9 (Add)                    (None, 5, 5, 728)    0           ['add_8[0][0]',
#                                                                   're_lu_34[0][0]']
#
#  re_lu_35 (ReLU)                (None, 5, 5, 728)    0           ['add_9[0][0]']
#
#  separable_conv2d_27 (Separable  (None, 5, 5, 728)   536536      ['re_lu_35[0][0]']
#  Conv2D)
#
#  batch_normalization_32 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_27[0][0]']
#  ormalization)
#
#  re_lu_36 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_32[0][0]']
#
#  separable_conv2d_28 (Separable  (None, 5, 5, 728)   536536      ['re_lu_36[0][0]']
#  Conv2D)
#
#  batch_normalization_33 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_28[0][0]']
#  ormalization)
#
#  re_lu_37 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_33[0][0]']
#
#  separable_conv2d_29 (Separable  (None, 5, 5, 728)   536536      ['re_lu_37[0][0]']
#  Conv2D)
#
#  batch_normalization_34 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_29[0][0]']
#  ormalization)
#
#  re_lu_38 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_34[0][0]']
#
#  add_10 (Add)                   (None, 5, 5, 728)    0           ['add_9[0][0]',
#                                                                   're_lu_38[0][0]']
#
#  re_lu_39 (ReLU)                (None, 5, 5, 728)    0           ['add_10[0][0]']
#
#  separable_conv2d_30 (Separable  (None, 5, 5, 728)   536536      ['re_lu_39[0][0]']
#  Conv2D)
#
#  batch_normalization_35 (BatchN  (None, 5, 5, 728)   2912        ['separable_conv2d_30[0][0]']
#  ormalization)
#
#  re_lu_40 (ReLU)                (None, 5, 5, 728)    0           ['batch_normalization_35[0][0]']
#
#  separable_conv2d_31 (Separable  (None, 5, 5, 1024)  752024      ['re_lu_40[0][0]']
#  Conv2D)
#
#  conv2d_5 (Conv2D)              (None, 3, 3, 1024)   745472      ['add_10[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 5, 5, 1024)  4096        ['separable_conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 3, 3, 1024)  4096        ['conv2d_5[0][0]']
#  ormalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 3, 3, 1024)  0           ['batch_normalization_36[0][0]']
#
#  add_11 (Add)                   (None, 3, 3, 1024)   0           ['batch_normalization_37[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  separable_conv2d_32 (Separable  (None, 3, 3, 1536)  1582080     ['add_11[0][0]']
#  Conv2D)
#
#  batch_normalization_38 (BatchN  (None, 3, 3, 1536)  6144        ['separable_conv2d_32[0][0]']
#  ormalization)
#
#  re_lu_41 (ReLU)                (None, 3, 3, 1536)   0           ['batch_normalization_38[0][0]']
#
#  separable_conv2d_33 (Separable  (None, 3, 3, 2048)  3159552     ['re_lu_41[0][0]']
#  Conv2D)
#
#  batch_normalization_39 (BatchN  (None, 3, 3, 2048)  8192        ['separable_conv2d_33[0][0]']
#  ormalization)
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['batch_normalization_39[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 12)           24588       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 20,886,068
# Trainable params: 20,831,540
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %% [markdown]
# ### Configuring the Model for Training

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Setting checkpoints
early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, verbose=1)

filepath_best="/kaggle/working/weights.best.hdf5"
checkpoint_best = ModelCheckpoint(filepath=filepath_best, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

filepath_full="/kaggle/working/weights.last_auto4.hdf5"
checkpoints_full = ModelCheckpoint(filepath=filepath_full, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

callbacks_list = [early_stopping, reduce_lr, checkpoint_best, checkpoints_full]

# %% [markdown]
# ### Training the Model

# %%
hist = model.fit(datagen.flow(trainX, trainY, batch_size=75), epochs=100, validation_data=(valX, valY), callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 43/43 [==============================] - 31s 185ms/step - loss: 2.4894 - accuracy: 0.3228 - val_loss: 87870336.0000 - val_accuracy: 0.1282 - lr: 0.0100
# Epoch 2/100
# 43/43 [==============================] - 7s 159ms/step - loss: 1.4497 - accuracy: 0.4818 - val_loss: 10609.5742 - val_accuracy: 0.1282 - lr: 0.0100
# Epoch 3/100
# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.savefig('model_acc_loss')
plt.show()

# %%
# Saving the model
model.save("x")
model.save_weights("weights.h5")

# %%
# Evaluating the model
valLoss, valAcc = model.evaluate(valX, valY, verbose=2)

print(f'Test loss: {valLoss}')
print(f'Test accuracy: {valAcc}')
# Out:
# 49/49 - 1s - loss: 0.2059 - accuracy: 0.9375 - 705ms/epoch - 14ms/step
# Test loss: 0.20591145753860474
# Test accuracy: 0.9375

# %%
# Making predictions
predV =  np.argmax(model.predict(valX), axis=1)
# Out:
# 49/49 [==============================] - 1s 14ms/step

# %%
# Exporting a classification report
from sklearn.metrics import classification_report

valYC = decode(encoder, np.argmax(valY, axis=1))
predVC = decode(encoder, predV)

print(classification_report(valYC, predVC))
# Out:
#                            precision    recall  f1-score   support
#
#               Black-grass       0.61      0.60      0.60        87
#                  Charlock       0.96      1.00      0.98       129
#                  Cleavers       0.98      0.94      0.96        95
#          Common Chickweed       0.97      1.00      0.98       201
#              Common wheat       0.93      0.92      0.92        73
#                   Fat Hen       0.99      0.99      0.99       157
#          Loose Silky-bent       0.85      0.86      0.86       216
#                     Maize       0.93      0.96      0.95        73
#         Scentless Mayweed       0.98      0.96      0.97       170
#           Shepherds Purse       0.99      0.93      0.96        76
# Small-flowered Cranesbill       0.99      0.99      0.99       164
#                Sugar beet       0.99      0.98      0.99       127
#
#                  accuracy                           0.94      1568
#                 macro avg       0.93      0.93      0.93      1568
#              weighted avg       0.94      0.94      0.94      1568

# %%
import numpy as np
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay

cm = confusion_matrix(valYC, predVC)
import numpy as np
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(valYC, predVC)

species = ["Black-grass", 
           "Charlock", 
           "Cleavers", 
           "Common Chickweed", 
           "Common wheat", 
           "Fat Hen", 
           "Loose Silky-bent", 
           "Maize", 
           "Scentless Mayweed", 
           "Shepherds Purse", 
           "Small-flowered Cranesbill", 
           "Sugar beet"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=species)

disp.plot(cmap="Blues", xticks_rotation=90)
plt.show()

# %% [markdown]
# ## Verifying with the Test Data

# %%
def loadTestData(path):
    X = []
    fName = []
    for img in glob.glob(path + "/*.png"):
        #reads the image as Blue-Green-Red
        image = cv2.imread(img)
        #converts the image to red-green-blue
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = cv2.resize(image, (70, 70))
        X.append(image)
        fName.append(img.split("/")[-1])
    return X, fName

def preprocessingTest(X):
    ppX = []
    for img in X:
        ppX.append(applyMask(img))
    ppX = np.array(ppX)
    normX = norm(ppX)
    return normX

# %%
testD, tName = loadTestData(testPath)

# %%
ppTD = preprocessingTest(testD)

# %%
yPred =  np.argmax(model.predict(ppTD), axis=1)
# Out:
# 25/25 [==============================] - 1s 15ms/step

# %%
predictions = pd.DataFrame({
    "file": tName,
    "species": decode(encoder, yPred)
})

predictions.head()
# Out:
#             file           species
# 0  fd87b36ae.png  Loose Silky-bent
# 1  0e8492cb1.png             Maize
# 2  8d6acbe9b.png  Common Chickweed
# 3  54b3afd58.png          Cleavers
# 4  6049234e6.png           Fat Hen

# %%
predictions.to_csv("predictions01.csv", index=False)
